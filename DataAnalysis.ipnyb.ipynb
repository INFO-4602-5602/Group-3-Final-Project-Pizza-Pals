# %%
import pandas as pd

# %% [markdown]
# # Quick EDA

# %% [markdown]
# ## #1: Formulate your questions:
# 1. What are the least and most expensive cities for pizza?
# 2. What is the number of restaurants serving pizza per capita (100,000 residents) across the U.S.?
# 3. What is the median price of a large plain pizza across the U.S.?
# 4. Which cities have the most restaurants serving pizza per capita (100,000 residents)?

# %% [markdown]
# ## #2: Read in the data

# %%
df = pd.read_csv("Datafiniti_Pizza_Restaurants_and_the_Pizza_They_Sell_May19.csv")
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVz3Y-7h3D1zeR_xDAqm  2017-06-30T05:05:40Z  2019-05-01T15:43:09Z
# 1  AVweGPFF_7pvs4fzAAzQ  2016-04-02T04:02:49Z  2019-05-01T15:27:50Z
# 2  AVwdRGa9_7pvs4fz4E3K  2016-03-03T18:39:49Z  2019-05-01T12:52:25Z
# 3  AVwdX4psIN2L1WUfvJB1  2016-03-29T05:08:59Z  2019-05-01T12:52:20Z
# 4  AVwdaeTtkufWRAb55pSH  2016-03-31T02:34:04Z  2019-05-01T12:50:45Z
#
#              address                                         categories  \
# 0   4203 E Kiehl Ave  Pizza,Restaurant,American restaurants,Pizza Pl...
# 1  25 E Camelback Rd                      Pizza,Pizza Place,Restaurants
# 2    3703 Paxton Ave                 Restaurant,Pizza Place,Restaurants
# 3    30495 John R Rd       Pizza,Carry-out food,Pizza Place,Restaurants
# 4   3600 Eastern Ave  Pizza,American restaurants,Pizza Place,Pizza e...
#
#                primaryCategories             city country  \
# 0  Accommodation & Food Services         Sherwood      US
# ...

# %% [markdown]
# ## #3: Check the packaging

# %%
df.shape
# Out:
# (10000, 24)

# %% [markdown]
# ## #4: Look at the top and bottom

# %%
df.head()
df.tail()
# Out:
#                         id             dateAdded           dateUpdated  \
# 9995  AVwdKXFYByjofQCxmIyZ  2016-03-21T00:12:46Z  2018-01-08T10:25:27Z
# 9996  AVwdKXFYByjofQCxmIyZ  2016-03-21T00:12:46Z  2018-01-08T10:25:27Z
# 9997  AVz6kzsQFcQ3k02bDhwQ  2017-06-30T19:56:11Z  2018-01-07T10:51:29Z
# 9998  AVz6kzsQFcQ3k02bDhwQ  2017-06-30T19:56:11Z  2018-01-07T10:51:29Z
# 9999  AVwdG9zTkufWRAb52Y2A  2015-10-23T01:57:27Z  2018-01-04T17:57:59Z
#
#                     address                              categories  \
# 9995      1126 E Lovejoy St                             Pizza Place
# 9996      1126 E Lovejoy St                             Pizza Place
# 9997         3641 E Main St                 Pizza Place,Restaurants
# 9998         3641 E Main St                 Pizza Place,Restaurants
# 9999  7460 W Lake Mead Blvd  Pizza Place,Restaurant,Fast Food,Pizza
#
#                   primaryCategories           city country  \
# 9995  Accommodation & Food Services        Buffalo      US
# ...

# %% [markdown]
# ## #5: Check the n's

# %%
print("# of unique restaurants: ", len(df["name"].unique()))
print("# of restaurant categories: ", len(df["categories"].unique()))
print("# of cities: ", len(df["city"].unique()))
print("# of province: ", len(df["province"].unique()))
print("# of countries: ", len(df["country"].unique()))
print("# of currencies: ", len(df["menus.currency"].unique()))
# Out:
# # of unique restaurants:  1827
# # of restaurant categories:  456
# # of cities:  1028
# # of province:  44
# # of countries:  1
# # of currencies:  1

# %%
print("Min Min-Price: ", df["priceRangeMin"].min())
print("Max Min-Price: ", df["priceRangeMin"].max())
print("---")
print("Min Max-Price: ", df["priceRangeMax"].min())
print("Max Max-Price: ", df["priceRangeMax"].max())
# Out:
# Min Min-Price:  0
# Max Min-Price:  50
# ---
# Min Max-Price:  7
# Max Max-Price:  55

# %%
df.isna().sum()
# Out:
# id                       0
# dateAdded                0
# dateUpdated              0
# address                  0
# categories               0
# primaryCategories        0
# city                     0
# country                  0
# keys                     0
# latitude                 0
# longitude                0
# menuPageURL           8321
# menus.amountMax          0
# menus.amountMin          0
# menus.currency           0
# menus.dateSeen           0
# menus.description     6282
# menus.name               0
# name                     0
# postalCode               4
# priceRangeCurrency       0
# priceRangeMin            0
# priceRangeMax            0
# province                 0
# dtype: int64

# %% [markdown]
# # Look at Menus.name column

# %%
len(df["menus.name"].unique())
# Out:
# 4749

# %%
df["menus.name"].head()
# Out:
# 0    Cheese Pizza
# 1    Pizza Cookie
# 2    Pizza Blanca
# 3     Small Pizza
# 4       Pizza Sub
# Name: menus.name, dtype: object

# %% [markdown]
# ### Clean up column and add to groups

# %%
df["menus.name2"] = df["menus.name"]#.copy()
df["menus.name2"] = df["menus.name2"].replace({"ampquot" : '"'},regex=True)

# Toppings
df["menus.name2"][df["menus.name2"].str.contains("Topping|Items|Item")] = "# of Topping Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Supreme|Supremo|Delight")] = "Supreme Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Small Cheese Pizza|Medium Cheese Pizza|Large Cheese Pizza|Round Cheese|Cheese Pizza Slice|Traditional Cheese|Fresh Mozzarella")] = "Cheese Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Cheese Love|Plain Pizza|Plain Cheese|Classic Cheese Pizza|Four Cheese Pizza|Mozzarella Cheese Pizza|Cheese Pizza Pie|Tomato Sauce")] = "Cheese Pizza"
df["menus.name2"][df["menus.name2"].str.contains('Formaggi|Three Cheese|18" Cheese|Regular Cheese|Six Cheese|Classic Cheese|Basic Cheese|Extra Cheese|Slice of Cheese|Five Cheese|Slice Cheese')] = "Cheese Pizza"
df["menus.name2"][df["menus.name2"].str.contains('" Cheese|Ques')] = "Cheese Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Taco Pizza")] = "Taco Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Favorite|Original|Classic|House|Signature|Traditional Pizza|Flagship")] = "Signature Pizza"
df["menus.name2"][df["menus.name2"].str.contains("White|Blanco|Blanca|Bianc")] = "White Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Pepperoni Pizza|Pepperoni and")] = "Pepperoni Pizza"
df["menus.name2"][df["menus.name2"].str.contains("BBQ|Bbq|Barbeque|Barbecue|B.B.Q")] = "BBQ Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Eggplant Parm")] = "Eggplant Parmigiana Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Hawaii|Pineapple|Hawailan|Luau|Aloha")] = "Hawaiian Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Margherita|Margarita|Margharita")] = "Margherita Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Vegetarian|Vegan")] = "Vegetarian/Vegan Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Pesto Pizza")] = "Pesto Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Philly|Cheese Steak|Steak and Cheese|Steak & Cheese")] = "Philly Cheese Steak Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Buffalo Chicken Pizza")] = "Buffalo Chicken Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Burger Pizza|burger Pizza")] = "Burger Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Vegetable|Veggi|Broccoli Pizza|Garden")] = "Veggie Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Sausage Pizza")] = "Sausage Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Alfredo")] = "Alfredo Pizza"
df["menus.name2"][df["menus.name2"].str.contains('Breakfast|Brunch')] = "Breakfast Pizza"
df["menus.name2"][df["menus.name2"].str.contains('Lunch')] = "Lunch Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Caprese")] = "Caprese Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Tomato Pizza")] = "Tomato Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Meat Love|Meatlove|Meat Pizza|All Meat|Meat Eaters|Meats")] = "Meat Lovers Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Grandpa|Grandma|Nonn")] = "Grandma/Grandpa Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Spinach Pizza")] = "Spinach Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Ziti")] = "Baked Ziti Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Shrimp|Seafood|Fish|Tuna|Anchovies")] = "Seafood Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Deluxe")] = "Deluxe Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Marinara")] = "Marinara Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Combo Pizza|Combination")] = "Combo Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Potato")] = "Potato Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Works")] = "Works Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Beach")] = "Beach Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Meatball")] = "Meatball Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Gourmet")] = "Gourmet Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Chicken Bacon Ranch")] = "Chicken Bacon Ranch Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Pesto")] = "Pesto Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Garlic Pizza")] = "Garlic Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Artichoke")] = "Artichoke Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Fajita")] = "Fajita Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Buffalo|Grilled Chicken|Chicken Ranch|Chicken Parm|Chicken Wing Pizza|Garlic Chicken|Chicken Finger|Chicken Marsala|Chicken Bacon Ranch|Chicken F")] = "Chicken Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Wild Mushroom|Mushroom Pizza")] = "Mushroom Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Cowboy")] = "Cowboy Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Primavera")] = "Primavera Pizza"
df["menus.name2"][df["menus.name2"].str.contains("BLT|Blt")] = "BLT Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Everything")] = "Everything Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Rustica")] = "Rustica Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Penne|Lasagn")] = "Pasta Pizza"

# Types of Pizza
df["menus.name2"][df["menus.name2"].str.contains("Stuff")] = "Stuffed Pizza"
df["menus.name2"][df["menus.name2"].str.contains("GlutenFree|Gluten Free")] = "Gluten Free Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Regular")] = "Regular Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Half")] = "Half and Half Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Specialty|Pizza Special|World|Pizza of the")] = "Specialty Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Create|Build|Craft|Make Your Own")] = "Create Your Own Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Wings|wings")] = "Pizza and Wings Combo"
df["menus.name2"][df["menus.name2"].str.contains("Thin Crust|Super Thin")] = "Thin Crust"
df["menus.name2"][df["menus.name2"].str.contains("Pan Pizza")] = "Pan Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Deep Dish")] = "Deep Dish Pizza"
df["menus.name2"][df["menus.name2"].str.contains('Slices of Pizza|" Pizza|Pizzas')] = "Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Dough")] = "Pizza Dough"
df["menus.name2"][df["menus.name2"].str.contains("By the Slice|By The Slice|2 Slice|Pizza Slices|by the Slice|Slice of")] = "By the Slice"
df["menus.name2"][df["menus.name2"].str.contains("Pizza Roll|Pizza Log")] = "Pizza Roll"
df["menus.name2"][df["menus.name2"].str.contains("Whole Wheat")] = "Whole Wheat Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Gyro")] = "Gyro Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Hand Tossed")] = "Hand Tossed Pizza"

# Origin
df["menus.name2"][df["menus.name2"].str.contains("New York|NY|Brooklyn|N. Y.")] = "New York Style Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Sicil")] = "Sicilian Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Neopolitan|Neapolitan")] = "Neopolitan Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Chicago")] = "Chicago Style Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Greek")] = "Greek Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Mexican")] = "Mexican Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Mediterranean")] = "Mediterranean Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Tuscan")] = "Tuscan Pizza"
df["menus.name2"][df["menus.name2"].str.contains("California")] = "California Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Napoli")] = "Napoli Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Capri")] = "Capri Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Thai")] = "Thai Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Italia|Roma|Milan|Bari|Luciano")] = "Italian Pizza"

# Sizes
df["menus.name2"][df["menus.name2"].str.contains("Kid|Baby")] = "Kids Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Mini")] = "Mini Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Individual|Personal")] = "Personal Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Small Pizza|Sample")] = "Small Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Medium Pizza")] = "Medium Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Any Large|Extra Large|Large Pizza|XLarge|Jumbo")] = "Large Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Sheet")] = "Sheet Pizza"
df["menus.name2"][df["menus.name2"].str.contains("2nd|Second|Deal")] = "Pizza Deal"

# Pizza Alternatives
df["menus.name2"][df["menus.name2"].str.contains("Pizza Fries")] = "Pizza Fries"
df["menus.name2"][df["menus.name2"].str.contains("Sub|Sandwich|Boat")] = "Pizza Sub"
df["menus.name2"][df["menus.name2"].str.contains("Salad Pizza|Pizza Salad")] = "Salad Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Dessert Pizza|Chocolate|Nutella|S39mores|Smores|S'mores")] = "Dessert Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Pizza Steak")] = "Pizza Steak"
df["menus.name2"][df["menus.name2"].str.contains("Pizza Burger")] = "Pizza Burger"
df["menus.name2"][df["menus.name2"].str.contains("Calzone|Stromboli")] = "Calzone/Stromboli"
df["menus.name2"][df["menus.name2"].str.contains("Bread")] = "Pizza Bread"
df["menus.name2"][df["menus.name2"].str.contains("Pizza Sauce")] = "Pizza Sauce"
df["menus.name2"][df["menus.name2"].str.contains("Pizzaiola")] = "Pizzaiola Pizza"
df["menus.name2"][df["menus.name2"].str.contains("Puff|Pocket|Pizza Pop")] = "Pizza Pocket"
df["menus.name2"][df["menus.name2"].str.contains("Dog")] = "Pizza Dog"
# Out:
# /Users/hannahweber/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/hannahweber/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/hannahweber/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# ...

# %%
df["menus.name2"].value_counts().sort_values(ascending = False).head(20)
# Out:
# Cheese Pizza              682
# White Pizza               536
# # of Topping Pizza        433
# Chicken Pizza             401
# Veggie Pizza              347
# Hawaiian Pizza            302
# BBQ Pizza                 271
# Pizza                     240
# Margherita Pizza          237
# Signature Pizza           203
# Meat Lovers Pizza         185
# Gluten Free Pizza         184
# Pepperoni Pizza           169
# Sicilian Pizza            158
# Stuffed Pizza             148
# Supreme Pizza             140
# Pizza Sub                 130
# Vegetarian/Vegan Pizza    117
# By the Slice              113
# Grandma/Grandpa Pizza     103
# Name: menus.name2, dtype: int64

# %%
#df["menus.name2"][df["menus.name2"].str.contains("Dog")] = "Pizza Dog"

# %%
#df[df["menus.name2"].str.contains("Phil")]

# %%
len(df["menus.name2"].unique())
# Out:
# 1440

# %% [markdown]
# ### Make a groupby and new csv

# %%
df.columns
# Out:
# Index(['id', 'dateAdded', 'dateUpdated', 'address', 'categories',
#        'primaryCategories', 'city', 'country', 'keys', 'latitude', 'longitude',
#        'menuPageURL', 'menus.amountMax', 'menus.amountMin', 'menus.currency',
#        'menus.dateSeen', 'menus.description', 'menus.name', 'name',
#        'postalCode', 'priceRangeCurrency', 'priceRangeMin', 'priceRangeMax',
#        'province', 'menus.name2'],
#       dtype='object')

# %%
df[['city', 'country','menus.amountMax', 'menus.amountMin','name', 'postalCode',
    'priceRangeMin', 'priceRangeMax', 'province', 'menus.name2']].to_csv("cleaned_pizza.csv")

# %% [markdown]
# ### Make a word cloud

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

text = str(df['menus.name2'])
wordcloud = WordCloud(max_font_size=100, max_words=50, background_color="white").generate(text)
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

wordcloud.to_file('MostUsedWords.png')

# %% [markdown]
# ### Find top pizza in each state

# %%
df.columns
# Out:
# Index(['id', 'dateAdded', 'dateUpdated', 'address', 'categories',
#        'primaryCategories', 'city', 'country', 'keys', 'latitude', 'longitude',
#        'menuPageURL', 'menus.amountMax', 'menus.amountMin', 'menus.currency',
#        'menus.dateSeen', 'menus.description', 'menus.name', 'name',
#        'postalCode', 'priceRangeCurrency', 'priceRangeMin', 'priceRangeMax',
#        'province', 'menus.name2'],
#       dtype='object')

# %%
a = df.groupby(["province", "menus.name2"]).agg({"postalCode" : "count"}).reset_index().rename(columns = {"postalCode" : "count"})
a = a.sort_values(["province", "count"], ascending = False)
a["province"].unique()
#a[a["province"] == "AK"]
# Out:
# array(['WV', 'WI', 'WA', 'VA', 'UT', 'TX', 'TN', 'SD', 'SC', 'PA', 'OR',
#        'OK', 'OH', 'NY', 'NV', 'NM', 'NJ', 'NE', 'ND', 'NC', 'MT', 'MS',
#        'MO', 'MN', 'MI', 'MD', 'LA', 'KY', 'KS', 'IN', 'IL', 'ID', 'IA',
#        'HI', 'GA', 'FL', 'DE', 'CT', 'CO', 'CA', 'AZ', 'AR', 'AL', 'AK'],
#       dtype=object)

# %%
pd.read_excel("Popular_State.xlsx")
# Out:
#    province            menus.name2  count
# 0        WV              Pizza Pie      5
# 1        WI     # of Topping Pizza     13
# 2        WA           Cheese Pizza     17
# 3        VA            White Pizza     22
# 4        UT      Gluten Free Pizza     14
# 5        TX           Cheese Pizza     43
# 6        TN     # of Topping Pizza      9
# 7        SD             Kids Pizza      2
# 8        SC           Cheese Pizza     13
# 9        PA           Cheese Pizza     60
# 10       OR      Gluten Free Pizza     15
# 11       OK     # of Topping Pizza      6
# 12       OH     # of Topping Pizza     37
# 13       NY            White Pizza    197
# 14       NV           Cheese Pizza     13
# 15       NM      Gluten Free Pizza      3
# 16       NJ            Large Pizza      1
# 17       NE           Cheese Pizza      5
# 18       ND          Chicken Pizza      2
# 19       NC            White Pizza     26
# 20       MT           Medium Pizza      1
# ...
